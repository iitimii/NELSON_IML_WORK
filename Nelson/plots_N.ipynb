# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('IML.csv')

# %%
df
# Out:
#      Unnamed: 0   Unnamed: 1           Unnamed: 2       Slip Detection  \
# 0           NaN          NaN                  NaN                  DNN
# 1             ​           ​1                    2                    3
# 2     Accuracy​  0.985761561  ​0.9852825916572324  ​0.9841940259514065
# 3    Precision​  0.947478294          0.973144127  ​0.9658341934579922
# 4      F_score​  0.947106976  ​0.9418166771722591  ​0.9378643116893338
# ..          ...          ...                  ...                  ...
# 352         NaN          NaN                  NaN                  NaN
# 353         NaN          NaN                  NaN                  NaN
# 354         NaN          NaN                  NaN                  NaN
# 355         NaN          NaN                  NaN                  NaN
# 356         NaN          NaN                  NaN                  NaN
#
#      Unnamed: 4  Unnamed: 5   Unnamed: 6   Unnamed: 7  Unnamed: 8 Unnamed: 9  \
# 0           NaN         NaN          NaN          NaN         NaN        NaN
# 1      4.000000    5.000000         Mean      Std Dev         NaN        NaN
# 2      0.984150    0.985631  0.985180992  0.000894834         NaN        NaN
# 3      0.949393    0.956822   0.95670958  0.011674046         NaN        NaN
# 4      0.939941    0.945334  0.944127194  0.003732413         NaN        NaN
# ..          ...         ...          ...          ...         ...        ...
# 352         NaN         NaN          NaN          NaN         NaN        NaN
# 353         NaN         NaN          NaN          NaN         NaN        NaN
# 354         NaN         NaN          NaN          NaN         NaN        NaN
# 355         NaN         NaN          NaN          NaN         NaN        NaN
# 356         NaN         NaN          NaN          NaN         NaN        NaN
#
#      ... Unnamed: 15 Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 0    ...         NaN         NaN          NaN          NaN          NaN
# 1    ...         NaN         NaN          NaN          NaN          NaN
# 2    ...         NaN         NaN          NaN          NaN          NaN
# 3    ...         NaN         NaN          NaN          NaN          NaN
# 4    ...         NaN         NaN          NaN          NaN          NaN
# ..   ...         ...         ...          ...          ...          ...
# 352  ...         NaN         NaN          NaN          NaN          NaN
# 353  ...         NaN         NaN          NaN          NaN          NaN
# 354  ...         NaN         NaN          NaN          NaN          NaN
# 355  ...         NaN         NaN          NaN          NaN          NaN
# 356  ...         NaN         NaN          NaN          NaN          NaN
#
#      Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 352          NaN          NaN          NaN          NaN          NaN
# 353          NaN          NaN          NaN          NaN          NaN
# 354          NaN          NaN          NaN          NaN          NaN
# 355          NaN          NaN          NaN          NaN          NaN
# 356          NaN          NaN          NaN          NaN          NaN
#
# [357 rows x 25 columns]

# %%
DNN = df['Unnamed: 6'].iloc[2:6].values.astype('float64')
CNN = df['Unnamed: 6'].iloc[8:12].values.astype('float64')
CNN_SMOTE = df['Unnamed: 6'].iloc[14:18].values.astype('float64')
RNN = df['Unnamed: 6'].iloc[20:24].values.astype('float64')
LSTM = df['Unnamed: 6'].iloc[26:30].values.astype('float64')
CONV_LSTM = df['Unnamed: 6'].iloc[32:36].values.astype('float64')


DNN_STD = df['Unnamed: 7'].iloc[2:6].values.astype('float64')
CNN_STD = df['Unnamed: 7'].iloc[8:12].values.astype('float64')
CNN_SMOTE_STD = df['Unnamed: 7'].iloc[14:18].values.astype('float64')
RNN_STD = df['Unnamed: 7'].iloc[20:24].values.astype('float64')
LSTM_STD = df['Unnamed: 7'].iloc[26:30].values.astype('float64')
CONV_LSTM_STD = df['Unnamed: 7'].iloc[32:36].values.astype('float64')


MOD = [DNN, CNN, CNN_SMOTE, RNN, LSTM, CONV_LSTM]
MOD_STD = [DNN_STD, CNN_STD, CNN_SMOTE_STD, RNN_STD, LSTM_STD, CONV_LSTM_STD]
mods = ['DNN', 'CNN', 'CNN_SMOTE', 'RNN', 'LSTM', 'CONV_LSTM']

ACC = [i[0] for i in MOD]
PREC = [i[1] for i in MOD]
F1= [i[2] for i in MOD]
RECALL = [i[3] for i in MOD]

ACC_STD = [i[0] for i in MOD_STD]
PREC_STD = [i[1] for i in MOD_STD]
F1_STD= [i[2] for i in MOD_STD]
RECALL_STD = [i[3] for i in MOD_STD]


fig = plt.subplots(figsize =(10, 7))
plt.title('Accuracy vs classification model')
plt.bar(mods, ACC, width=0.5, yerr=ACC_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('Accuracy')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()

fig = plt.subplots(figsize =(10, 7))
plt.title('Precision vs classification model')
plt.bar(mods, PREC, width=0.5, yerr=PREC_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('Precision')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()


fig = plt.subplots(figsize =(10, 7))
plt.title('F-score vs classification model')
plt.bar(mods, F1, width=0.5, yerr=F1_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('F-score')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()


fig = plt.subplots(figsize =(10, 7))
plt.title('Recall vs classification model')
plt.bar(mods, RECALL, width=0.5, yerr=RECALL_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('Recall')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()

# %%
# T + 5

DNN = df['Unnamed: 6'].iloc[40:44].values.astype('float64')
CNN = df['Unnamed: 6'].iloc[65:69].values.astype('float64')
CNN_SMOTE = df['Unnamed: 9'].iloc[65:69].values.astype('float64')
RNN = df['Unnamed: 6'].iloc[90:94].values.astype('float64')
LSTM = df['Unnamed: 6'].iloc[112:116].values.astype('float64')
CONV_LSTM = df['Unnamed: 1'].iloc[134:138].values.astype('float64')


DNN_STD = df['Unnamed: 7'].iloc[40:44].values.astype('float64')
CNN_STD = df['Unnamed: 7'].iloc[65:69].values.astype('float64')
CNN_SMOTE_STD = df['Unnamed: 11'].iloc[65:69].values.astype('float64')
RNN_STD = df['Unnamed: 7'].iloc[90:94].values.astype('float64')
LSTM_STD = df['Unnamed: 7'].iloc[112:116].values.astype('float64')
CONV_LSTM_STD = df['Slip Detection'].iloc[134:138].values.astype('float64')

MOD = [DNN, CNN, CNN_SMOTE, RNN, LSTM, CONV_LSTM]
MOD_STD = [DNN_STD, CNN_STD, CNN_SMOTE_STD, RNN_STD, LSTM_STD, CONV_LSTM_STD]
mods = ['DNN', 'CNN', 'CNN_SMOTE', 'RNN', 'LSTM', 'CONV_LSTM']

ACC = [i[0] for i in MOD]
PREC = [i[1] for i in MOD]
F1= [i[2] for i in MOD]
RECALL = [i[3] for i in MOD]

ACC_STD = [i[0] for i in MOD_STD]
PREC_STD = [i[1] for i in MOD_STD]
F1_STD= [i[2] for i in MOD_STD]
RECALL_STD = [i[3] for i in MOD_STD]



fig = plt.subplots(figsize =(10, 7))
plt.title('Accuracy vs Classification model (T + 5)')
plt.bar(mods, ACC, width=0.5, yerr=ACC_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('Accuracy')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()


fig = plt.subplots(figsize =(10, 7))
plt.title('Precison vs Classification model (T + 5)')
plt.bar(mods, PREC, width=0.5, yerr=PREC_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('Precison')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()


fig = plt.subplots(figsize =(10, 7))
plt.title('F-score vs classification model (T + 5)')
plt.bar(mods, F1, width=0.5, yerr=F1_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('F-score')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()

fig = plt.subplots(figsize =(10, 7))
plt.title('Recall vs Classification model (T + 5)')
plt.bar(mods, RECALL, width=0.5, yerr=RECALL_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('Recall')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()

# %%
#T + 10

DNN = df['Unnamed: 6'].iloc[46:50].values.astype('float64')
CNN = df['Unnamed: 6'].iloc[71:75].values.astype('float64')
CNN_SMOTE = df['Unnamed: 9'].iloc[71:75].values.astype('float64')
RNN = df['Unnamed: 6'].iloc[95:99].values.astype('float64')
LSTM = df['Unnamed: 6'].iloc[117:121].values.astype('float64')
CONV_LSTM = df['Unnamed: 1'].iloc[139:143].values.astype('float64')


DNN_STD = df['Unnamed: 7'].iloc[46:50].values.astype('float64')
CNN_STD = df['Unnamed: 7'].iloc[71:75].values.astype('float64')
CNN_SMOTE_STD = df['Unnamed: 11'].iloc[71:75].values.astype('float64')
RNN_STD = df['Unnamed: 7'].iloc[95:99].values.astype('float64')
LSTM_STD = df['Unnamed: 7'].iloc[117:121].values.astype('float64')
CONV_LSTM_STD = df['Slip Detection'].iloc[139:143].values.astype('float64')

MOD = [DNN, CNN, CNN_SMOTE, RNN, LSTM, CONV_LSTM]
MOD_STD = [DNN_STD, CNN_STD, CNN_SMOTE_STD, RNN_STD, LSTM_STD, CONV_LSTM_STD]
mods = ['DNN', 'CNN', 'CNN_SMOTE', 'RNN', 'LSTM', 'CONV_LSTM']

ACC = [i[0] for i in MOD]
PREC = [i[1] for i in MOD]
F1= [i[2] for i in MOD]
RECALL = [i[3] for i in MOD]

ACC_STD = [i[0] for i in MOD_STD]
PREC_STD = [i[1] for i in MOD_STD]
F1_STD= [i[2] for i in MOD_STD]
RECALL_STD = [i[3] for i in MOD_STD]

fig = plt.subplots(figsize =(10, 7))
plt.title('Accuracy vs Classification model (T + 10)')
plt.bar(mods, ACC, width=0.5, yerr=ACC_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('Accuracy')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()

fig = plt.subplots(figsize =(10, 7))
plt.title('Precison vs Classification model (T + 10)')
plt.bar(mods, PREC, width=0.5, yerr=PREC_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('Precison')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()

fig = plt.subplots(figsize =(10, 7))
plt.title('F-score vs classification model (T + 10)')
plt.bar(mods, F1, width=0.5, yerr=F1_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('F-score')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()

fig = plt.subplots(figsize =(10, 7))
plt.title('Recall vs Classification model (T + 10)')
plt.bar(mods, RECALL, width=0.5, yerr=RECALL_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('Recall')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()

# %%
# T + 15

DNN = df['Unnamed: 6'].iloc[52:56].values.astype('float64')
CNN = df['Unnamed: 6'].iloc[77:81].values.astype('float64')
CNN_SMOTE = df['Unnamed: 9'].iloc[77:81].values.astype('float64')
RNN = df['Unnamed: 6'].iloc[100:104].values.astype('float64')
LSTM = df['Unnamed: 6'].iloc[122:126].values.astype('float64')
CONV_LSTM = df['Unnamed: 1'].iloc[144:148].values.astype('float64')


DNN_STD = df['Unnamed: 7'].iloc[52:56].values.astype('float64')
CNN_STD = df['Unnamed: 7'].iloc[77:81].values.astype('float64')
CNN_SMOTE_STD = df['Unnamed: 11'].iloc[77:81].values.astype('float64')
RNN_STD = df['Unnamed: 7'].iloc[100:104].values.astype('float64')
LSTM_STD = df['Unnamed: 7'].iloc[122:126].values.astype('float64')
CONV_LSTM_STD = df['Slip Detection'].iloc[144:148].values.astype('float64')

MOD = [DNN, CNN, CNN_SMOTE, RNN, LSTM, CONV_LSTM]
MOD_STD = [DNN_STD, CNN_STD, CNN_SMOTE_STD, RNN_STD, LSTM_STD, CONV_LSTM_STD]
mods = ['DNN', 'CNN', 'CNN_SMOTE', 'RNN', 'LSTM', 'CONV_LSTM']

ACC = [i[0] for i in MOD]
PREC = [i[1] for i in MOD]
F1= [i[2] for i in MOD]
RECALL = [i[3] for i in MOD]

ACC_STD = [i[0] for i in MOD_STD]
PREC_STD = [i[1] for i in MOD_STD]
F1_STD= [i[2] for i in MOD_STD]
RECALL_STD = [i[3] for i in MOD_STD]




fig = plt.subplots(figsize =(10, 7))
plt.title('Accuracy vs Classification model (T + 15)')
plt.bar(mods, ACC, width=0.5, yerr=ACC_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('Accuracy')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()

fig = plt.subplots(figsize =(10, 7))
plt.title('Precison vs Classification model (T + 15)')
plt.bar(mods, PREC, width=0.5, yerr=PREC_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('Precison')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()

fig = plt.subplots(figsize =(10, 7))
plt.title('F-score vs classification model (T + 15)')
plt.bar(mods, F1, width=0.5, yerr=F1_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('F-score')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()

fig = plt.subplots(figsize =(10, 7))
plt.title('Recall vs Classification model (T + 15)')
plt.bar(mods, RECALL, width=0.5, yerr=RECALL_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('Recall')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()

# %%
# T + 20


DNN = df['Unnamed: 6'].iloc[58:62].values.astype('float64')
CNN = df['Unnamed: 6'].iloc[83:87].values.astype('float64')
CNN_SMOTE = df['Unnamed: 9'].iloc[83:87].values.astype('float64')
RNN = df['Unnamed: 6'].iloc[105:109].values.astype('float64')
LSTM = df['Unnamed: 6'].iloc[127:131].values.astype('float64')
CONV_LSTM = df['Unnamed: 1'].iloc[149:153].values.astype('float64')


DNN_STD = df['Unnamed: 7'].iloc[58:62].values.astype('float64')
CNN_STD = df['Unnamed: 7'].iloc[83:87].values.astype('float64')
CNN_SMOTE_STD = df['Unnamed: 11'].iloc[83:87].values.astype('float64')
RNN_STD = df['Unnamed: 7'].iloc[105:109].values.astype('float64')
LSTM_STD = df['Unnamed: 7'].iloc[127:131].values.astype('float64')
CONV_LSTM_STD = df['Slip Detection'].iloc[149:153].values.astype('float64')

MOD = [DNN, CNN, CNN_SMOTE, RNN, LSTM, CONV_LSTM]
MOD_STD = [DNN_STD, CNN_STD, CNN_SMOTE_STD, RNN_STD, LSTM_STD, CONV_LSTM_STD]
mods = ['DNN', 'CNN', 'CNN_SMOTE', 'RNN', 'LSTM', 'CONV_LSTM']

ACC = [i[0] for i in MOD]
PREC = [i[1] for i in MOD]
F1= [i[2] for i in MOD]
RECALL = [i[3] for i in MOD]

ACC_STD = [i[0] for i in MOD_STD]
PREC_STD = [i[1] for i in MOD_STD]
F1_STD= [i[2] for i in MOD_STD]
RECALL_STD = [i[3] for i in MOD_STD]




fig = plt.subplots(figsize =(10, 7))
plt.title('Accuracy vs Classification model (T + 20)')
plt.bar(mods, ACC, width=0.5, yerr=ACC_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('Accuracy')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()

fig = plt.subplots(figsize =(10, 7))
plt.title('Precison vs Classification model (T + 20)')
plt.bar(mods, PREC, width=0.5, yerr=PREC_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('Precison')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()

fig = plt.subplots(figsize =(10, 7))
plt.title('F-score vs classification model (T + 20)')
plt.bar(mods, F1, width=0.5, yerr=F1_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('F-score')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()

fig = plt.subplots(figsize =(10, 7))
plt.title('Recall vs Classification model (T + 20)')
plt.bar(mods, RECALL, width=0.5, yerr=RECALL_STD)
plt.yticks(np.arange(0, 1, 0.1))
plt.ylabel('Recall')
plt.ylim(0.7)
plt.yticks(np.arange(0.7, 1, 0.05))
plt.show()
